# %%
import os
from google.colab import files

if not os.path.exists('/content/kaggle.json'):
    print("Please upload your kaggle.json file:")
    uploaded = files.upload()

# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d mohitsingh1804/plantvillage

# !mkdir -p /content/PlantVillage
# !unzip -q plantvillage.zip -d /content/PlantVillage

print("Dataset downloaded and extracted successfully into '/content/PlantVillage'!")
# Out:
# Please upload your kaggle.json file:
#      <input type="file" id="files-5b28deab-be96-4cfd-ac0a-002f40eee158" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b28deab-be96-4cfd-ac0a-002f40eee158">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11m-cls.pt")

model.train(
    data="/content/PlantVillage/PlantVillage",
    epochs=3,
    imgsz=224,
    batch=32,
    device=0,
    project="Agriculture_CV",
    name="disease_classifier"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files

weight_path = "/content/runs/classify/Agriculture_CV/disease_classifier-2/weights/best.pt"
files.download(weight_path)
